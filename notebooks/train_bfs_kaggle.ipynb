# %%
# !git clone https://github.com/MarkoMile/nar-experiments.git
# %cd nar-experiments
# !pip install torch==2.8.0 torchvision==0.23.0 torchaudio==2.8.0 --index-url https://download.pytorch.org/whl/cu126
# !pip install torch-scatter -f https://data.pyg.org/whl/torch-2.8.0+cu126.html
# !pip install torch-geometric
# !pip install lightning
# !pip install ogb yacs loguru
# !pip install "salsa-clrs @ git+https://github.com/jkminder/SALSA-CLRS.git"
# !pip install "dm-clrs @ git+https://github.com/deepmind/clrs.git"
# !pip install -q numpy scipy networkx ogb matplotlib tqdm scikit-learn

# %%
import sys
import tqdm.notebook
import tqdm.auto

# 1. Force the auto-detector to use the notebook version
tqdm.auto.tqdm = tqdm.notebook.tqdm
tqdm.auto.trange = tqdm.notebook.trange

# %%
# %run src/experiments/train_bfs.py --cfg src/configs/bfs/GIN.yml --seed 42
